# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori

# %%
dataset = pd.read_csv('Oder3.csv', header = None)
dataset
# Out:
#                    0              1                 2          3        4
# 0      TransactionNo          Items          DateTime    Daypart  DayType
# 1                  1          Bread   10/30/2016 9:58    Morning  Weekend
# 2                  2   Scandinavian  10/30/2016 10:05    Morning  Weekend
# 3                  2   Scandinavian  10/30/2016 10:05    Morning  Weekend
# 4                  3  Hot chocolate  10/30/2016 10:07    Morning  Weekend
# ...              ...            ...               ...        ...      ...
# 20503           9682         Coffee    9/4/2017 14:32  Afternoon  Weekend
# 20504           9682            Tea    9/4/2017 14:32  Afternoon  Weekend
# 20505           9683         Coffee    9/4/2017 14:57  Afternoon  Weekend
# 20506           9683         Pastry    9/4/2017 14:57  Afternoon  Weekend
# 20507           9684      Smoothies    9/4/2017 15:04  Afternoon  Weekend
#
# [20508 rows x 5 columns]

# %%
transactions = []
for i in range(0, 20508):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 5)])

# %%
# Training Apriori algorithm on the dataset
rule_list = apriori(transactions, min_support = 0.0003, min_confidence = 0.5, min_lift = 3, min_length = 2)

# %%
# Visualizing the list of rules
results = list(rule_list)
for i in results:
    print('\n')
    print(i)
    print('**********')
# Out:
# RelationRecord(items=frozenset({'1/13/2017 14:26', '4629'}), support=0.000341330212599961, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1/13/2017 14:26'}), items_add=frozenset({'4629'}), confidence=1.0, lift=2929.714285714286), OrderedStatistic(items_base=frozenset({'4629'}), items_add=frozenset({'1/13/2017 14:26'}), confidence=1.0, lift=2929.714285714286)])
# **********
#
#
# RelationRecord(items=frozenset({'1/14/2017 12:55', '4692'}), support=0.000341330212599961, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1/14/2017 12:55'}), items_add=frozenset({'4692'}), confidence=1.0, lift=2929.714285714286), OrderedStatistic(items_base=frozenset({'4692'}), items_add=frozenset({'1/14/2017 12:55'}), confidence=1.0, lift=2929.714285714286)])
# **********
#
#
# ...
